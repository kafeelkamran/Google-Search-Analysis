# %%
# !pip install pytrends

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %%
trends.build_payload(kw_list=["Machine Learning"])
data = trends.interest_by_region()
data = data.sort_values(by="Machine Learning", ascending=False)
data = data.head(10)
print(data)
# Out:
#              Machine Learning
# geoName
# China                     100
# Ethiopia                   56
# Singapore                  51
# India                      42
# Tunisia                    32
# Sri Lanka                  32
# Pakistan                   30
# Hong Kong                  29
# South Korea                29
# Kenya                      27

# %%
data.reset_index().plot(x="geoName", y="Machine Learning", figsize=(20,10), kind="bar")
plt.style.use('fivethirtyeight')
plt.ylabel("Machine Learning")
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Machine Learning'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['Machine Learning'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Machine Learning', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %%
trends.build_payload(kw_list=["Deep Learning"])
data = trends.interest_by_region()
data = data.sort_values(by="Deep Learning", ascending=False)
data = data.head(10)
print(data)
# Out:
#              Deep Learning
# geoName
# China                  100
# South Korea             23
# Ethiopia                19
# Hong Kong               14
# Tunisia                 14
# Singapore               14
# Pakistan                 9
# Israel                   8
# India                    8
# Taiwan                   7

# %%
data.reset_index().plot(x="geoName", y="Deep Learning", figsize=(20,10), kind="bar")
plt.style.use('fivethirtyeight')
plt.ylabel("Deep Learning")
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Deep Learning'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['Deep Learning'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Deep Learning', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %%
trends.build_payload(kw_list=["Data Science"])
data = trends.interest_by_region()
data = data.sort_values(by="Data Science", ascending=False)
data = data.head(10)
print(data)
# Out:
#            Data Science
# geoName
# Zimbabwe            100
# India                85
# Kenya                82
# Ethiopia             79
# Singapore            75
# Nigeria              71
# China                70
# Pakistan             61
# Sri Lanka            60
# Ghana                58

# %%
data.reset_index().plot(x="geoName", y="Data Science", figsize=(20,10), kind="bar")
plt.style.use('fivethirtyeight')
plt.ylabel("Data Science")
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Data Science'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['Data Science'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Data Science', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %%
trends.build_payload(kw_list=["NLP"])
data = trends.interest_by_region()
data = data.sort_values(by="NLP", ascending=False)
data = data.head(10)
print(data)
# Out:
#                       NLP
# geoName
# China                 100
# Israel                 48
# Singapore              22
# Netherlands            22
# Hong Kong              20
# United Arab Emirates   18
# Ethiopia               17
# India                  16
# Serbia                 16
# Slovenia               16

# %%
data.reset_index().plot(x="geoName", y="NLP", figsize=(20,10), kind="bar")
plt.style.use('fivethirtyeight')
plt.ylabel("NLP")
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['NLP'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['NLP'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for NLP', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
